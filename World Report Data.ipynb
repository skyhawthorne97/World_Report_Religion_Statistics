# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/Users/Davy/Downloads/WRP_global.csv")

# %%
df.head()
# Out:
#    year    chrstprot     chrstcat    chrstorth    chrstang   chrstothr  \
# 0  1945  160,887,585  391,332,035   98,501,171  36,955,033  13,674,466
# 1  1950  133,301,043  401,935,856  106,610,911  38,307,544  16,324,768
# 2  1955  189,347,338  474,378,130  111,661,338  38,177,572  22,437,724
# 3  1960  220,293,770  541,957,872  118,268,109  41,846,700  44,601,144
# 4  1965  234,437,703  614,115,021  125,954,494  45,086,639  55,119,929
#
#         chrstgen    judorth     jdcons     judref  ... taogenpct jaingenpct  \
# 0    701,350,290    856,827  1,426,350  1,929,388  ...    0.0001     0.0000
# 1    696,480,122  2,204,231  1,860,297  2,528,641  ...    0.0004     0.0008
# 2    836,002,102  2,496,432  1,653,007  2,225,241  ...    0.0005     0.0006
# 3    966,967,595  2,818,847  1,716,903  2,300,405  ...    0.0005     0.0007
# 4  1,074,713,786  3,295,632  1,760,345  2,348,076  ...    0.0005     0.0007
#
#   confgenpct syncgenpct anmgenpct  nonreligpct othrgenpct sumreligpct  \
# ...

# %%
plt.plot(df['chrstang'], color = 'blue')
plt.ylabel('Number')
plt.xlabel('Years since 1945')
plt.title('Angelical Christian vs. Buddhist Affiliation')
plt.plot(df['budthr'], color = 'purple')
plt.show()

# %%
plt.hist(df[])
